# %% [markdown]
# # Cleaning up the Titanic Dataset

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\MR.OKECH\Desktop\Joshua\Data Career\Matering Python for DA\Titanic Dataset\Titanic-Dataset.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.shape
# Out:
# (891, 12)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df['Age'] = df['Age'].round(1)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[['Last name', 'Rest']] = df['Name'].str.split(', ', expand = True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[['Title', 'First_Middle_Nmaes']] = df['Rest'].str.split(' ', n=1, expand = True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop(columns = ['Name', 'Rest'], inplace = True)
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          887         0       2    male  27.0      0      0
# 887          888         1       1  female  19.0      0      0
# 888          889         0       3  female  29.7      1      2
# 889          890         1       1    male  26.0      0      0
# 890          891         0       3    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked  Last name  Title  \
# 0           A/5 21171   7.2500   NaN        S     Braund    Mr.
# 1            PC 17599  71.2833   C85        C    Cumings   Mrs.
# ...

# %%
df['Sex'] = df['Sex'].str.replace('male', 'Male')
df['Sex'] = df['Sex'].str.replace('feMale', 'Female')

df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    Male  22.0      1      0
# 1              2         1       1  Female  38.0      1      0
# 2              3         1       3  Female  26.0      0      0
# 3              4         1       1  Female  35.0      1      0
# 4              5         0       3    Male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          887         0       2    Male  27.0      0      0
# 887          888         1       1  Female  19.0      0      0
# 888          889         0       3  Female  29.7      1      2
# 889          890         1       1    Male  26.0      0      0
# 890          891         0       3    Male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked  Last name  Title  \
# 0           A/5 21171   7.2500   NaN        S     Braund    Mr.
# 1            PC 17599  71.2833   C85        C    Cumings   Mrs.
# ...

# %%
df['Cabin'] = df['Cabin'].fillna('')
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    Male  22.0      1      0
# 1              2         1       1  Female  38.0      1      0
# 2              3         1       3  Female  26.0      0      0
# 3              4         1       1  Female  35.0      1      0
# 4              5         0       3    Male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          887         0       2    Male  27.0      0      0
# 887          888         1       1  Female  19.0      0      0
# 888          889         0       3  Female  29.7      1      2
# 889          890         1       1    Male  26.0      0      0
# 890          891         0       3    Male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked  Last name  Title  \
# 0           A/5 21171   7.2500              S     Braund    Mr.
# 1            PC 17599  71.2833   C85        C    Cumings   Mrs.
# ...

# %%
df[['First Name', 'Middle_Nmaes']] = df['First_Middle_Nmaes'].str.split(' ', n=1, expand = True)
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    Male  22.0      1      0
# 1              2         1       1  Female  38.0      1      0
# 2              3         1       3  Female  26.0      0      0
# 3              4         1       1  Female  35.0      1      0
# 4              5         0       3    Male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          887         0       2    Male  27.0      0      0
# 887          888         1       1  Female  19.0      0      0
# 888          889         0       3  Female  29.7      1      2
# 889          890         1       1    Male  26.0      0      0
# 890          891         0       3    Male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked  Last name  Title  \
# 0           A/5 21171   7.2500              S     Braund    Mr.
# 1            PC 17599  71.2833   C85        C    Cumings   Mrs.
# ...

# %%
df[['Middle Name', 'Other Name9s0']] = df['Middle_Nmaes'].str.split(' ', n=1, expand = True)
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    Male  22.0      1      0
# 1              2         1       1  Female  38.0      1      0
# 2              3         1       3  Female  26.0      0      0
# 3              4         1       1  Female  35.0      1      0
# 4              5         0       3    Male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          887         0       2    Male  27.0      0      0
# 887          888         1       1  Female  19.0      0      0
# 888          889         0       3  Female  29.7      1      2
# 889          890         1       1    Male  26.0      0      0
# 890          891         0       3    Male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked  Last name  Title  \
# 0           A/5 21171   7.2500              S     Braund    Mr.
# 1            PC 17599  71.2833   C85        C    Cumings   Mrs.
# ...

# %%
df.drop(columns = ['First_Middle_Nmaes', 'Middle_Nmaes'], inplace = True)
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    Male  22.0      1      0
# 1              2         1       1  Female  38.0      1      0
# 2              3         1       3  Female  26.0      0      0
# 3              4         1       1  Female  35.0      1      0
# 4              5         0       3    Male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          887         0       2    Male  27.0      0      0
# 887          888         1       1  Female  19.0      0      0
# 888          889         0       3  Female  29.7      1      2
# 889          890         1       1    Male  26.0      0      0
# 890          891         0       3    Male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked  Last name  Title First Name  \
# 0           A/5 21171   7.2500              S     Braund    Mr.       Owen
# ...

# %%
# New column order
new_column_order = ['PassengerId', 'Survived', 'Pclass', 'Title', 'First Name', 'Middle Name', 'Last name', 'Other Name9s0', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

df = df[new_column_order]
df
# Out:
#      PassengerId  Survived  Pclass  Title First Name Middle Name  Last name  \
# 0              1         0       3    Mr.       Owen      Harris     Braund
# 1              2         1       1   Mrs.       John     Bradley    Cumings
# 2              3         1       3  Miss.      Laina        None  Heikkinen
# 3              4         1       1   Mrs.    Jacques       Heath   Futrelle
# 4              5         0       3    Mr.    William       Henry      Allen
# ..           ...       ...     ...    ...        ...         ...        ...
# 886          887         0       2   Rev.     Juozas        None   Montvila
# 887          888         1       1  Miss.   Margaret       Edith     Graham
# 888          889         0       3  Miss.  Catherine       Helen   Johnston
# 889          890         1       1    Mr.       Karl      Howell       Behr
# 890          891         0       3    Mr.    Patrick        None     Dooley
#
# ...

# %%
df = df.rename(columns = {'First Name': 'FirstName', 'Middle Name': 'MiddleName', 'Last name': 'LastName', 'Other Name9s0': 'OtherName(s)'})
df
# Out:
#      PassengerId  Survived  Pclass  Title  FirstName MiddleName   LastName  \
# 0              1         0       3    Mr.       Owen     Harris     Braund
# 1              2         1       1   Mrs.       John    Bradley    Cumings
# 2              3         1       3  Miss.      Laina       None  Heikkinen
# 3              4         1       1   Mrs.    Jacques      Heath   Futrelle
# 4              5         0       3    Mr.    William      Henry      Allen
# ..           ...       ...     ...    ...        ...        ...        ...
# 886          887         0       2   Rev.     Juozas       None   Montvila
# 887          888         1       1  Miss.   Margaret      Edith     Graham
# 888          889         0       3  Miss.  Catherine      Helen   Johnston
# 889          890         1       1    Mr.       Karl     Howell       Behr
# 890          891         0       3    Mr.    Patrick       None     Dooley
#
# ...

# %%
df['OtherName(s)'] = df['OtherName(s)'].str.replace(r'[^a-zA-Z\s]', '', regex=True)
df
# Out:
#      PassengerId  Survived  Pclass  Title  FirstName MiddleName   LastName  \
# 0              1         0       3    Mr.       Owen     Harris     Braund
# 1              2         1       1   Mrs.       John    Bradley    Cumings
# 2              3         1       3  Miss.      Laina       None  Heikkinen
# 3              4         1       1   Mrs.    Jacques      Heath   Futrelle
# 4              5         0       3    Mr.    William      Henry      Allen
# ..           ...       ...     ...    ...        ...        ...        ...
# 886          887         0       2   Rev.     Juozas       None   Montvila
# 887          888         1       1  Miss.   Margaret      Edith     Graham
# 888          889         0       3  Miss.  Catherine      Helen   Johnston
# 889          890         1       1    Mr.       Karl     Howell       Behr
# 890          891         0       3    Mr.    Patrick       None     Dooley
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PassengerId   891 non-null    int64
#  1   Survived      891 non-null    int64
#  2   Pclass        891 non-null    int64
#  3   Title         891 non-null    object
#  4   FirstName     891 non-null    object
#  5   MiddleName    576 non-null    object
#  6   LastName      891 non-null    object
#  7   OtherName(s)  188 non-null    object
#  8   Sex           891 non-null    object
#  9   Age           891 non-null    float64
#  10  SibSp         891 non-null    int64
#  11  Parch         891 non-null    int64
#  12  Ticket        891 non-null    object
#  13  Fare          891 non-null    float64
#  14  Cabin         891 non-null    object
#  15  Embarked      889 non-null    object
# dtypes: float64(2), int64(5), object(9)
# memory usage: 111.5+ KB

# %%
df[df['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass  Title FirstName MiddleName LastName  \
# 61            62         1       1  Miss.    Amelie       None    Icard
# 829          830         1       1   Mrs.    George     Nelson    Stone
#
#       OtherName(s)     Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61            None  Female  38.0      0      0  113572  80.0   B28      NaN
# 829  Martha Evelyn  Female  62.0      0      0  113572  80.0   B28      NaN

# %% [markdown]
# The null values under the 'Embarked' column have to be filled, preferrably with the modal value of 'Embarked'

# %%
# Find the most common value in 'Embarked'
most_frequent = df['Embarked'].mode()[0]
print(most_frequent)
# Out:
# S

# %%
# Fill null values with the mode
df['Embarked'].fillna("S", inplace=True)

# Confirm that there are no longer any null values
df[df['Embarked'].isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Title, FirstName, MiddleName, LastName, OtherName(s), Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Box plot to visualize outliers
sns.boxplot(x=df['Fare'])
plt.show()

# %%
# Specify the columns you're interested in
cols = ['Age', 'Fare', 'Pclass']

# Compute correlation matrix for the specified columns
correlation_matrix = df[cols].corr()

# Plot heatmap for the correlation matrix of selected columns
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()
